# %%
import pandas as pd
import json
import os

with open('/content/annotations.json', 'r') as f:
    data = json.load(f)

# %%
entity_name = "NOUN", "PROPN", "VERB"\

train_data = data['annotations']
train_data = [tuple(i) for i in train_data]

# %%
train_data
# Out:
# [('Buscamos un Desarrollador de Software Senior para unirse a nuestro equipo de tecnología en la empresa XYZ. El candidato ideal tendrá una sólida experiencia en el desarrollo de aplicaciones web y móviles, así como en la implementación de soluciones de software escalables.\r',
#   {'entities': [[0, 8, 'VERB'],
#     [12, 25, 'NOUN'],
#     [29, 37, 'NOUN'],
#     [38, 44, 'NOUN'],
#     [50, 56, 'VERB'],
#     [67, 73, 'NOUN'],
#     [77, 87, 'NOUN'],
#     [94, 101, 'NOUN'],
#     [102, 106, 'PROPN'],
#     [110, 119, 'NOUN'],
#     [126, 132, 'VERB'],
#     [144, 155, 'NOUN'],
#     [162, 172, 'NOUN'],
#     [176, 188, 'NOUN'],
#     [189, 192, 'NOUN'],
#     [195, 202, 'NOUN'],
#     [219, 233, 'VERB'],
#     [237, 247, 'NOUN'],
#     [251, 259, 'NOUN'],
#     [260, 270, 'NOUN']]}),
#  ('Se busca un ingeniero de software con experiencia en el desarrollo de aplicaciones web y móviles para unirse al equipo de XYZ Inc. en San Francisco.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 21, 'NOUN'],
#     [25, 33, 'NOUN'],
#     [38, 49, 'NOUN'],
#     [56, 66, 'NOUN'],
#     [70, 82, 'NOUN'],
#     [83, 86, 'NOUN'],
#     [89, 96, 'NOUN'],
#     [102, 108, 'VERB'],
#     [122, 130, 'PROPN'],
#     [134, 147, 'PROPN']]}),
#  ('Se busca un arquitecto de soluciones con experiencia en implementación de proyectos en la nube para unirse al equipo de ABC Tech en su sede en Nueva York. La persona seleccionada será responsable de diseñar soluciones escalables y sostenibles para los clientes de la compañía.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 36, 'NOUN'],
#     [56, 83, 'NOUN'],
#     [90, 94, 'NOUN'],
#     [100, 106, 'VERB'],
#     [110, 116, 'NOUN'],
#     [120, 128, 'PROPN'],
#     [135, 139, 'NOUN'],
#     [143, 154, 'PROPN'],
#     [158, 165, 'NOUN'],
#     [179, 183, 'VERB'],
#     [184, 195, 'NOUN'],
#     [199, 206, 'VERB'],
#     [207, 217, 'NOUN'],
#     [252, 260, 'NOUN'],
#     [267, 275, 'NOUN']]}),
#  ('Se busca un data scientist con experiencia en análisis de datos y modelos de aprendizaje automático para unirse al equipo de DEF Corp en su sede en Londres. La persona seleccionada trabajará en proyectos importantes para la compañía y utilizará técnicas avanzadas para extraer insights valiosos de los datos.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 26, 'NOUN'],
#     [46, 63, 'NOUN'],
#     [66, 99, 'NOUN'],
#     [105, 111, 'VERB'],
#     [115, 121, 'NOUN'],
#     [125, 133, 'PROPN'],
#     [140, 144, 'NOUN'],
#     [148, 156, 'PROPN'],
#     [160, 167, 'NOUN'],
#     [181, 190, 'VERB'],
#     [194, 203, 'NOUN'],
#     [224, 232, 'NOUN'],
#     [235, 244, 'VERB'],
#     [245, 253, 'NOUN'],
#     [269, 276, 'VERB'],
#     [277, 285, 'NOUN'],
#     [302, 307, 'NOUN']]}),
#  ('Se busca un ingeniero de software full-stack con experiencia en desarrollo de aplicaciones en React y Node.js para unirse al equipo de GHI Inc en su sede en San Francisco. La persona seleccionada será responsable de desarrollar y mantener aplicaciones web escalables y eficientes, trabajando en estrecha colaboración con el equipo de diseño y el equipo de productos.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 33, 'NOUN'],
#     [34, 44, 'NOUN'],
#     [49, 60, 'NOUN'],
#     [64, 90, 'NOUN'],
#     [94, 99, 'NOUN'],
#     [102, 109, 'NOUN'],
#     [115, 121, 'VERB'],
#     [125, 131, 'NOUN'],
#     [135, 142, 'PROPN'],
#     [149, 153, 'NOUN'],
#     [157, 171, 'PROPN'],
#     [175, 182, 'NOUN'],
#     [196, 200, 'VERB'],
#     [216, 227, 'VERB'],
#     [230, 238, 'VERB'],
#     [239, 255, 'NOUN'],
#     [281, 291, 'VERB'],
#     [304, 316, 'NOUN'],
#     [324, 340, 'NOUN'],
#     [346, 365, 'NOUN']]}),
#  ('El puesto de Ejecutivo de Ventas B2B requiere una persona altamente motivada y orientada a resultados para unirse a nuestro equipo en la región de San Francisco. El candidato ideal tiene experiencia en la venta de soluciones tecnológicas a grandes empresas y está listo para desarrollar relaciones comerciales duraderas y generar oportunidades de crecimiento.\r',
#   {'entities': [[3, 9, 'NOUN'],
#     [13, 22, 'NOUN'],
#     [26, 32, 'NOUN'],
#     [37, 45, 'VERB'],
#     [50, 57, 'NOUN'],
#     [107, 113, 'VERB'],
#     [124, 130, 'NOUN'],
#     [137, 143, 'NOUN'],
#     [147, 161, 'PROPN'],
#     [165, 174, 'NOUN'],
#     [181, 186, 'VERB'],
#     [248, 256, 'NOUN'],
#     [259, 263, 'VERB'],
#     [264, 269, 'VERB'],
#     [275, 286, 'VERB'],
#     [287, 297, 'NOUN'],
#     [298, 309, 'NOUN'],
#     [322, 329, 'VERB'],
#     [330, 343, 'NOUN'],
#     [347, 358, 'NOUN']]}),
#  ('Buscamos un Representante de Ventas Senior para unirse a nuestro equipo en Nueva York. El candidato ideal tiene una sólida trayectoria en ventas y experiencia en el sector tecnológico. Será responsable de establecer y mantener relaciones con clientes, identificar oportunidades de crecimiento y superar objetivos de ventas.\r',
#   {'entities': [[0, 8, 'VERB'],
#     [12, 25, 'NOUN'],
#     [29, 35, 'NOUN'],
#     [36, 42, 'NOUN'],
#     [48, 54, 'VERB'],
#     [65, 71, 'NOUN'],
#     [75, 86, 'PROPN'],
#     [90, 99, 'NOUN'],
#     [106, 111, 'VERB'],
#     [123, 134, 'NOUN'],
#     [138, 144, 'NOUN'],
#     [165, 171, 'NOUN'],
#     [172, 184, 'NOUN'],
#     [185, 189, 'VERB'],
#     [190, 201, 'NOUN'],
#     [205, 215, 'VERB'],
#     [218, 226, 'VERB'],
#     [227, 237, 'NOUN'],
#     [242, 250, 'NOUN'],
#     [252, 263, 'VERB'],
#     [264, 277, 'NOUN'],
#     [281, 292, 'NOUN'],
#     [295, 302, 'VERB'],
#     [303, 312, 'NOUN']]}),
#  ('Necesitamos un Director de Ventas para liderar nuestro equipo de ventas en Dallas. El candidato ideal tiene una sólida experiencia en la gestión de equipos de ventas y un historial comprobado de lograr objetivos de ventas. Será responsable de establecer estrategias de ventas, supervisar la actividad de ventas y asegurar la satisfacción del cliente.\r',
#   {'entities': [[0, 11, 'VERB'],
#     [15, 23, 'NOUN'],
#     [27, 33, 'NOUN'],
#     [39, 46, 'VERB'],
#     [55, 61, 'NOUN'],
#     [75, 82, 'PROPN'],
#     [86, 95, 'NOUN'],
#     [102, 118, 'VERB'],
#     [119, 130, 'NOUN'],
#     [137, 144, 'NOUN'],
#     [148, 155, 'NOUN'],
#     [159, 165, 'NOUN'],
#     [171, 180, 'NOUN'],
#     [202, 211, 'NOUN'],
#     [215, 222, 'NOUN'],
#     [223, 227, 'VERB'],
#     [228, 239, 'NOUN'],
#     [243, 253, 'VERB'],
#     [254, 265, 'NOUN'],
#     [269, 275, 'NOUN'],
#     [277, 287, 'VERB'],
#     [291, 300, 'NOUN'],
#     [304, 310, 'NOUN'],
#     [313, 321, 'VERB'],
#     [325, 337, 'NOUN'],
#     [342, 349, 'NOUN']]}),
#  ('Buscamos un Asistente Administrativo para unirse a nuestro equipo en la empresa ABC Inc. El candidato será responsable de apoyar al departamento de administración en tareas diarias y en el mantenimiento de registros organizados.\r',
#   {'entities': [[0, 8, 'VERB'],
#     [12, 36, 'NOUN'],
#     [42, 48, 'VERB'],
#     [59, 65, 'NOUN'],
#     [72, 79, 'NOUN'],
#     [80, 88, 'PROPN'],
#     [92, 101, 'NOUN'],
#     [102, 106, 'VERB'],
#     [107, 118, 'NOUN'],
#     [122, 128, 'VERB'],
#     [132, 144, 'NOUN'],
#     [148, 162, 'NOUN'],
#     [166, 172, 'NOUN'],
#     [189, 202, 'VERB'],
#     [206, 215, 'NOUN']]}),
#  ('La empresa XYZ busca un Coordinador de Recursos Humanos para liderar y supervisar las operaciones HR de la organización. El candidato ideal debe tener experiencia en gestión de recursos humanos y habilidades de liderazgo sólidas.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [15, 20, 'VERB'],
#     [24, 55, 'NOUN'],
#     [61, 68, 'VERB'],
#     [71, 81, 'VERB'],
#     [86, 97, 'NOUN'],
#     [98, 100, 'NOUN'],
#     [107, 120, 'NOUN'],
#     [124, 133, 'NOUN'],
#     [140, 144, 'VERB'],
#     [145, 150, 'VERB'],
#     [151, 162, 'NOUN'],
#     [166, 173, 'NOUN'],
#     [177, 193, 'NOUN'],
#     [196, 207, 'NOUN'],
#     [211, 220, 'NOUN']]}),
#  ('Se requiere un Asistente de Ventas para unirse al equipo de ventas de la empresa DEF Ltd. El candidato será responsable de apoyar a los ejecutivos de ventas en la gestión de clientes, la generación de leads y la realización de seguimiento a prospectos.\r',
#   {'entities': [[3, 11, 'VERB'],
#     [15, 34, 'NOUN'],
#     [40, 46, 'VERB'],
#     [50, 56, 'NOUN'],
#     [60, 66, 'NOUN'],
#     [73, 80, 'NOUN'],
#     [81, 89, 'PROPN'],
#     [93, 102, 'NOUN'],
#     [103, 107, 'VERB'],
#     [108, 119, 'NOUN'],
#     [123, 129, 'VERB'],
#     [136, 146, 'NOUN'],
#     [150, 156, 'NOUN'],
#     [163, 170, 'VERB'],
#     [174, 182, 'NOUN'],
#     [187, 197, 'VERB'],
#     [201, 206, 'NOUN'],
#     [212, 223, 'VERB'],
#     [227, 238, 'NOUN'],
#     [241, 251, 'NOUN']]}),
#  ('La compañía GHI busca un Contador Junior para unirse a su equipo contable. El candidato ideal tendrá experiencia en contabilidad y habilidades en la utilización de software contable. Será responsable de llevar a cabo tareas contables diarias y de brindar apoyo a la gerencia financiera.\r',
#   {'entities': [[3, 11, 'NOUN'],
#     [12, 15, 'PROPN'],
#     [16, 21, 'VERB'],
#     [25, 40, 'NOUN'],
#     [46, 52, 'VERB'],
#     [58, 64, 'NOUN'],
#     [65, 74, 'NOUN'],
#     [78, 87, 'NOUN'],
#     [88, 93, 'NOUN'],
#     [94, 100, 'VERB'],
#     [101, 112, 'NOUN'],
#     [116, 128, 'NOUN'],
#     [131, 142, 'NOUN'],
#     [149, 160, 'NOUN'],
#     [164, 172, 'NOUN'],
#     [173, 182, 'NOUN'],
#     [183, 187, 'VERB'],
#     [188, 199, 'NOUN'],
#     [203, 209, 'VERB'],
#     [212, 216, 'VERB'],
#     [217, 223, 'NOUN'],
#     [224, 233, 'NOUN'],
#     [247, 254, 'VERB'],
#     [255, 260, 'NOUN'],
#     [266, 285, 'NOUN']]}),
#  ('Se busca un Coordinador de Operaciones con experiencia en logística y gestión de equipos para unirse a la empresa XYZ. El candidato ideal tendrá una formación en administración de empresas y habilidades en liderazgo, planificación y resolución de problemas.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 38, 'NOUN'],
#     [43, 54, 'NOUN'],
#     [58, 67, 'NOUN'],
#     [70, 88, 'NOUN'],
#     [94, 100, 'VERB'],
#     [106, 113, 'NOUN'],
#     [114, 118, 'PROPN'],
#     [122, 131, 'NOUN'],
#     [138, 144, 'VERB'],
#     [149, 158, 'NOUN'],
#     [162, 188, 'NOUN'],
#     [191, 202, 'NOUN'],
#     [206, 215, 'NOUN'],
#     [217, 230, 'NOUN'],
#     [233, 256, 'NOUN']]}),
#  ('La empresa ABC está buscando un Especialista en Seguridad Operativa para garantizar la protección de sus activos y personal. El candidato ideal tendrá experiencia en implementación de políticas y procedimientos de seguridad, así como habilidades en investigación y resolución de incidentes.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [20, 28, 'VERB'],
#     [32, 67, 'NOUN'],
#     [73, 83, 'VERB'],
#     [87, 97, 'NOUN'],
#     [105, 112, 'NOUN'],
#     [115, 124, 'NOUN'],
#     [128, 137, 'NOUN'],
#     [144, 150, 'VERB'],
#     [151, 162, 'NOUN'],
#     [166, 180, 'VERB'],
#     [184, 193, 'NOUN'],
#     [196, 210, 'NOUN'],
#     [214, 223, 'NOUN'],
#     [234, 245, 'NOUN'],
#     [249, 262, 'NOUN'],
#     [265, 275, 'NOUN'],
#     [279, 289, 'NOUN']]}),
#  ('La compañía XYZ está buscando un Jefe de Operaciones para dirigir y supervisar el desempeño de sus equipos de trabajo. El candidato ideal tendrá una amplia experiencia en la gestión de proyectos y operaciones, así como habilidades en la toma de decisiones y resolución de problemas.\r',
#   {'entities': [[3, 11, 'NOUN'],
#     [12, 15, 'PROPN'],
#     [21, 29, 'VERB'],
#     [33, 52, 'NOUN'],
#     [58, 65, 'VERB'],
#     [68, 78, 'VERB'],
#     [82, 91, 'NOUN'],
#     [99, 106, 'NOUN'],
#     [110, 118, 'NOUN'],
#     [122, 131, 'NOUN'],
#     [138, 144, 'VERB'],
#     [156, 167, 'NOUN'],
#     [174, 181, 'VERB'],
#     [185, 194, 'NOUN'],
#     [197, 208, 'NOUN'],
#     [219, 230, 'NOUN'],
#     [237, 241, 'NOUN'],
#     [245, 255, 'NOUN'],
#     [258, 268, 'NOUN'],
#     [272, 281, 'NOUN']]}),
#  ('La empresa ABC está buscando un Especialista en Seguridad Operativa para garantizar la protección de sus activos y personal. El candidato ideal tendrá experiencia en implementación de políticas y procedimientos de seguridad, así como habilidades en investigación y resolución de incidentes.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [20, 28, 'VERB'],
#     [32, 67, 'NOUN'],
#     [73, 83, 'VERB'],
#     [87, 97, 'NOUN'],
#     [105, 112, 'NOUN'],
#     [115, 124, 'NOUN'],
#     [128, 137, 'NOUN'],
#     [144, 150, 'VERB'],
#     [151, 162, 'NOUN'],
#     [166, 180, 'VERB'],
#     [184, 193, 'NOUN'],
#     [196, 210, 'NOUN'],
#     [214, 223, 'NOUN'],
#     [234, 245, 'NOUN'],
#     [249, 262, 'NOUN'],
#     [265, 275, 'NOUN'],
#     [279, 289, 'NOUN']]}),
#  ('La empresa ABC busca un Gerente de Recursos Humanos para supervisar y administrar todas las funciones relacionadas con los empleados. El candidato ideal deberá tener experiencia en la implementación de políticas y programas de desarrollo de personal.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [15, 20, 'VERB'],
#     [24, 31, 'NOUN'],
#     [35, 51, 'NOUN'],
#     [57, 67, 'VERB'],
#     [70, 81, 'VERB'],
#     [92, 101, 'NOUN'],
#     [123, 133, 'NOUN'],
#     [137, 146, 'NOUN'],
#     [153, 159, 'VERB'],
#     [160, 165, 'VERB'],
#     [166, 177, 'NOUN'],
#     [184, 198, 'VERB'],
#     [202, 211, 'NOUN'],
#     [214, 223, 'NOUN'],
#     [227, 237, 'NOUN'],
#     [241, 249, 'NOUN']]}),
#  ('Se busca un Director Financiero para la empresa DEF. El candidato ideal tendrá una amplia experiencia en la planificación y gestión de las finanzas de la empresa, así como en la toma de decisiones estratégicas importantes.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 31, 'NOUN'],
#     [40, 47, 'NOUN'],
#     [48, 52, 'PROPN'],
#     [56, 65, 'NOUN'],
#     [72, 78, 'VERB'],
#     [90, 101, 'NOUN'],
#     [108, 121, 'VERB'],
#     [124, 131, 'VERB'],
#     [139, 147, 'NOUN'],
#     [154, 161, 'NOUN'],
#     [178, 182, 'VERB'],
#     [186, 196, 'NOUN'],
#     [197, 209, 'NOUN']]}),
#  ('La empresa GHI está buscando un Vicepresidente de Operaciones para supervisar y optimizar los procesos operativos y logísticos de la empresa. El candidato ideal tendrá una amplia experiencia en la implementación de soluciones eficientes.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [20, 28, 'VERB'],
#     [32, 46, 'NOUN'],
#     [50, 61, 'NOUN'],
#     [67, 77, 'VERB'],
#     [80, 89, 'VERB'],
#     [94, 102, 'NOUN'],
#     [116, 126, 'NOUN'],
#     [133, 141, 'NOUN'],
#     [145, 154, 'NOUN'],
#     [161, 167, 'VERB'],
#     [179, 190, 'NOUN'],
#     [197, 211, 'VERB'],
#     [215, 225, 'NOUN']]}),
#  ('La empresa JKL está buscando un Director de Desarrollo de Negocios para liderar la expansión de la empresa a nuevos mercados y fortalecer su posición en el mercado actual. El candidato ideal tendrá una amplia experiencia en la identificación y análisis de oportunidades de negocios.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [20, 28, 'VERB'],
#     [32, 40, 'NOUN'],
#     [44, 54, 'NOUN'],
#     [58, 66, 'NOUN'],
#     [72, 79, 'VERB'],
#     [83, 92, 'VERB'],
#     [99, 106, 'NOUN'],
#     [116, 124, 'NOUN'],
#     [127, 137, 'VERB'],
#     [141, 149, 'NOUN'],
#     [175, 184, 'NOUN'],
#     [191, 197, 'VERB'],
#     [209, 220, 'NOUN'],
#     [227, 241, 'VERB'],
#     [244, 252, 'VERB'],
#     [256, 269, 'NOUN'],
#     [273, 281, 'NOUN']]}),
#  ('La compañía XYZ está buscando un Director de Marketing para liderar la estrategia de marketing y crecimiento de la marca. El candidato ideal tendrá experiencia en el desarrollo de campañas de marketing digital y tradicionales, y en la supervisión de un equipo.\r',
#   {'entities': [[3, 11, 'NOUN'],
#     [12, 15, 'PROPN'],
#     [16, 29, 'VERB'],
#     [33, 41, 'NOUN'],
#     [45, 54, 'NOUN'],
#     [60, 67, 'VERB'],
#     [71, 81, 'NOUN'],
#     [85, 94, 'NOUN'],
#     [97, 108, 'NOUN'],
#     [115, 121, 'NOUN'],
#     [125, 134, 'NOUN'],
#     [141, 147, 'VERB'],
#     [148, 159, 'NOUN'],
#     [166, 176, 'VERB'],
#     [180, 188, 'NOUN'],
#     [192, 201, 'NOUN'],
#     [235, 246, 'VERB'],
#     [253, 259, 'NOUN']]}),
#  ('La empresa ABC está buscando un Experto en Marketing Digital para liderar la implementación de estrategias de marketing digital y mejorar la presencia en línea de la marca. El candidato ideal tendrá experiencia en SEO, SEM, email marketing y publicidad en redes sociales.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [15, 28, 'VERB'],
#     [32, 39, 'NOUN'],
#     [43, 60, 'NOUN'],
#     [66, 73, 'VERB'],
#     [77, 91, 'NOUN'],
#     [95, 106, 'NOUN'],
#     [110, 127, 'NOUN'],
#     [141, 150, 'NOUN'],
#     [154, 159, 'NOUN'],
#     [166, 172, 'NOUN'],
#     [176, 185, 'NOUN'],
#     [192, 198, 'VERB'],
#     [199, 210, 'VERB'],
#     [214, 217, 'NOUN'],
#     [219, 222, 'NOUN'],
#     [224, 239, 'NOUN'],
#     [242, 252, 'NOUN'],
#     [256, 270, 'NOUN']]}),
#  ('La empresa XYZ está buscando un Especialista en Campañas Publicitarias para desarrollar y ejecutar campañas de publicidad integradas a través de diferentes canales. El candidato ideal tendrá una fuerte comprensión de la investigación de mercado, segmentación de audiencias y desarrollo de estrategias de branding.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 14, 'PROPN'],
#     [15, 28, 'VERB'],
#     [32, 44, 'NOUN'],
#     [48, 70, 'NOUN'],
#     [76, 87, 'VERB'],
#     [90, 98, 'VERB'],
#     [99, 121, 'NOUN'],
#     [156, 164, 'NOUN'],
#     [168, 177, 'NOUN'],
#     [184, 190, 'VERB'],
#     [202, 213, 'VERB'],
#     [220, 244, 'NOUN'],
#     [246, 272, 'NOUN'],
#     [275, 300, 'NOUN'],
#     [304, 312, 'NOUN']]}),
#  ('Se busca un Analista Financiero para unirse a una empresa líder en el sector bancario. El candidato será responsable de llevar a cabo análisis financieros detallados y presentar recomendaciones para la toma de decisiones comerciales y estratégicas.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 31, 'NOUN'],
#     [37, 43, 'VERB'],
#     [50, 57, 'NOUN'],
#     [70, 86, 'NOUN'],
#     [90, 99, 'NOUN'],
#     [100, 116, 'VERB'],
#     [120, 133, 'VERB'],
#     [134, 154, 'NOUN'],
#     [168, 177, 'VERB'],
#     [178, 193, 'NOUN'],
#     [210, 232, 'NOUN'],
#     [235, 247, 'NOUN']]}),
#  ('Se busca un Asistente de Gerente de Inversiones para una empresa de gestión de activos en crecimiento. El candidato será responsable de ayudar en la investigación de oportunidades de inversión, monitorear y evaluar el desempeño de los portafolios, y preparar informes para los clientes y los gerentes de inversiones.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 47, 'NOUN'],
#     [57, 86, 'NOUN'],
#     [106, 115, 'NOUN'],
#     [136, 142, 'VERB'],
#     [149, 162, 'NOUN'],
#     [166, 192, 'NOUN'],
#     [194, 204, 'VERB'],
#     [207, 214, 'VERB'],
#     [218, 227, 'NOUN'],
#     [235, 246, 'NOUN'],
#     [250, 258, 'VERB'],
#     [259, 267, 'NOUN'],
#     [277, 285, 'NOUN'],
#     [292, 315, 'NOUN']]}),
#  ('Se busca un Analista de Riesgo Financiero para una firma de inversiones internacional. El candidato será responsable de evaluar y monitorear los riesgos financieros asociados con las inversiones, desarrollar estrategias para mitigar esos riesgos, y preparar informes regulares para el equipo de inversiones y los clientes.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 41, 'NOUN'],
#     [51, 71, 'NOUN'],
#     [90, 99, 'NOUN'],
#     [120, 127, 'VERB'],
#     [130, 140, 'VERB'],
#     [145, 164, 'NOUN'],
#     [183, 194, 'NOUN'],
#     [196, 207, 'VERB'],
#     [208, 219, 'NOUN'],
#     [249, 257, 'VERB'],
#     [258, 276, 'NOUN'],
#     [285, 306, 'NOUN'],
#     [313, 321, 'NOUN']]}),
#  ('El abogado senior será responsable de proporcionar asesoramiento legal a la empresa en diversas áreas, incluyendo contratos, propiedad intelectual, litigios y cumplimiento normativo. Además, trabajará estrechamente con otras áreas de la empresa para garantizar la integridad y el cumplimiento con las leyes y regulaciones aplicables.\r',
#   {'entities': [[3, 10, 'NOUN'],
#     [11, 17, 'NOUN'],
#     [18, 22, 'VERB'],
#     [23, 34, 'NOUN'],
#     [38, 50, 'VERB'],
#     [51, 70, 'NOUN'],
#     [76, 83, 'PROPN'],
#     [87, 101, 'NOUN'],
#     [114, 123, 'NOUN'],
#     [125, 146, 'NOUN'],
#     [148, 156, 'NOUN'],
#     [159, 182, 'NOUN'],
#     [191, 200, 'VERB'],
#     [225, 244, 'NOUN'],
#     [250, 260, 'VERB'],
#     [264, 274, 'NOUN'],
#     [280, 292, 'NOUN'],
#     [301, 306, 'NOUN'],
#     [309, 321, 'NOUN'],
#     [322, 332, 'NOUN']]}),
#  ('Se busca un Contador/a Senior para unirse a la firma de contabilidad y auditoría Smith & Associates. El/la candidato/a deberá tener experiencia en la elaboración y revisión de estados financieros y en la planificación fiscal. Se requiere un título universitario en contabilidad y una certificación activa.\r',
#   {'entities': [[3, 8, 'VERB'],
#     [12, 22, 'NOUN'],
#     [23, 29, 'NOUN'],
#     [35, 41, 'VERB'],
#     [47, 52, 'NOUN'],
#     [56, 68, 'NOUN'],
#     [71, 80, 'NOUN'],
#     [81, 100, 'PROPN'],
#     [107, 118, 'NOUN'],
#     [126, 131, 'VERB'],
#     [132, 143, 'NOUN'],
#     [150, 161, 'VERB'],
#     [164, 172, 'VERB'],
#     [176, 195, 'NOUN'],
#     [229, 237, 'VERB'],
#     [241, 261, 'NOUN'],
#     [265, 277, 'NOUN'],
#     [284, 297, 'NOUN']]}),
#  ('Se requiere un auditor senior para unirse a la empresa Ernst & Young. El candidato ideal debe tener al menos 5 años de experiencia en auditoría financiera y haber obtenido su certificación en contabilidad. La posición incluye la supervisión de equipos y la realización de auditorías en una variedad de industrias.\r',
#   {'entities': [[3, 11, 'VERB'],
#     [15, 22, 'NOUN'],
#     [23, 29, 'NOUN'],
#     [35, 41, 'VERB'],
#     [47, 54, 'NOUN'],
#     [55, 69, 'PROPN'],
#     [73, 82, 'NOUN'],
#     [89, 93, 'VERB'],
#     [94, 99, 'VERB'],
#     [119, 130, 'NOUN'],
#     [134, 154, 'NOUN'],
#     [157, 171, 'VERB'],
#     [175, 188, 'NOUN'],
#     [192, 205, 'NOUN'],
#     [209, 217, 'NOUN'],
#     [218, 225, 'VERB'],
#     [229, 240, 'VERB'],
#     [244, 251, 'NOUN'],
#     [257, 268, 'VERB'],
#     [272, 282, 'NOUN'],
#     [290, 298, 'NOUN'],
#     [302, 312, 'NOUN']]}),
#  ('"ACCA": Association of Chartered Certified Accountants.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 54, 'PROPN']]}),
#  ('"CFE": Certified Fraud Examiner.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 31, 'PROPN']]}),
#  ('"CFA": Chartered Financial Analyst.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 34, 'PROPN']]}),
#  ('"CPA": Certified Public Accountant.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 34, 'PROPN']]}),
#  ('"CMA": Certified Management Accountant.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 38, 'PROPN']]}),
#  ('"CFP": Certified Financial Planner.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 34, 'PROPN']]}),
#  ('"CIA": Certified Internal Auditor.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 33, 'PROPN']]}),
#  ('"CFM": Certified Financial Manager.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 34, 'PROPN']]}),
#  ('"FRM": Financial Risk Manager.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 29, 'PROPN']]}),
#  ('"CGEIT": Certified in the Governance of Enterprise IT.\r',
#   {'entities': [[1, 6, 'PROPN'], [9, 53, 'PROPN']]}),
#  ('"CISA": Certified Information Systems Auditor.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 45, 'PROPN']]}),
#  ('"CTP": Certified Treasury Professional.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 38, 'PROPN']]}),
#  ('"CGMA": Chartered Global Management Accountant.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 46, 'PROPN']]}),
#  ('"CISSP": Certified Information Systems Security Professional.\r',
#   {'entities': [[1, 6, 'PROPN'], [9, 60, 'PROPN']]}),
#  ('"CEH": Certified Ethical Hacker.\r',
#   {'entities': [[1, 4, 'PROPN'], [7, 31, 'PROPN']]}),
#  ('"CISM": Certified Information Security Manager.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 46, 'PROPN']]}),
#  ('"CCSP": Certified Cloud Security Professional.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 45, 'PROPN']]}),
#  ('"CompTIA Security+": CompTIA Security+.\r',
#   {'entities': [[1, 18, 'PROPN'], [21, 38, 'PROPN']]}),
#  ('"GSEC": GIAC Security Essentials.\r',
#   {'entities': [[1, 5, 'PROPN'], [8, 32, 'PROPN']]}),
#  ('"CISSP-ISSAP": Certified Information Systems Security Professional (CISSP-ISSAP).\r',
#   {'entities': [[1, 12, 'PROPN'], [15, 66, 'PROPN']]}),
#  ('"CISSP-ISSMP": Certified Information Systems Security Professional (CISSP-ISSMP).',
#   {'entities': [[1, 12, 'PROPN'], [15, 66, 'PROPN']]}),
#  ('XYZ\r', {'entities': [[0, 3, 'NOUN']]}),
#  ('XYZ Inc.\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('San Francisco\r', {'entities': [[0, 13, 'NOUN']]}),
#  ('ABC Tech\r', {'entities': [[0, 8, 'NOUN']]}),
#  ('Nueva York\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('DEF Corp\r', {'entities': [[0, 8, 'NOUN']]}),
#  ('Londres\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('GHI Inc\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('San Francisco\r', {'entities': [[0, 13, 'NOUN']]}),
#  ('responsabilidad\r', {'entities': [[0, 15, 'NOUN']]}),
#  ('colaborar\r', {'entities': [[0, 9, 'VERB']]}),
#  ('Nueva York\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('Dallas\r', {'entities': [[0, 6, 'NOUN']]}),
#  ('supervisar\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('tener\r', {'entities': [[0, 5, 'VERB']]}),
#  ('tener una\r', {'entities': [[0, 9, 'VERB']]}),
#  ('tener un historial\r', {'entities': [[0, 18, 'VERB']]}),
#  ('ABC Inc\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('mantenimiento\r', {'entities': [[0, 13, 'NOUN']]}),
#  ('DEF Ltd\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('apoyar\r', {'entities': [[0, 6, 'NOUN']]}),
#  ('gestión\r', {'entities': [[0, 7, 'NOUN']]}),
#  ('realización\r', {'entities': [[0, 11, 'NOUN']]}),
#  ('GHI\r', {'entities': [[0, 3, 'NOUN']]}),
#  ('implementación\r', {'entities': [[0, 14, 'NOUN']]}),
#  ('supervisión\r', {'entities': [[0, 11, 'NOUN']]}),
#  ('administración\r', {'entities': [[0, 14, 'NOUN']]}),
#  ('planificación\r', {'entities': [[0, 13, 'NOUN']]}),
#  ('toma\r', {'entities': [[0, 4, 'NOUN']]}),
#  ('optimización\r', {'entities': [[0, 12, 'NOUN']]}),
#  ('liderazgo\r', {'entities': [[0, 9, 'NOUN']]}),
#  ('expansión\r', {'entities': [[0, 9, 'NOUN']]}),
#  ('identificación\r', {'entities': [[0, 14, 'NOUN']]}),
#  ('análisis\r', {'entities': [[0, 8, 'NOUN']]}),
#  ('desarrollo\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('experiencia\r', {'entities': [[0, 11, 'NOUN']]}),
#  ('ejecución\r', {'entities': [[0, 9, 'NOUN']]}),
#  ('fuerte comprensión\r', {'entities': [[0, 18, 'NOUN']]}),
#  ('monitoreo\r', {'entities': [[0, 9, 'NOUN']]}),
#  ('evaluación\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('investigar\r', {'entities': [[0, 10, 'VERB']]}),
#  ('mitigación\r', {'entities': [[0, 10, 'NOUN']]}),
#  ('empresas\r', {'entities': [[0, 8, 'NOUN']]}),
#  ('elaboración\r', {'entities': [[0, 11, 'NOUN']]}),
#  ('revisión\r', {'entities': [[0, 8, 'NOUN']]}),
#  ('realización\r', {'entities': [[0, 11, 'NOUN']]})]

# %%
for text, entities in train_data:
  for item in entities.values():
    entities['entities'] = [tuple(i) for i in item]

# %%
train_data
# Out:
# [('Buscamos un Desarrollador de Software Senior para unirse a nuestro equipo de tecnología en la empresa XYZ. El candidato ideal tendrá una sólida experiencia en el desarrollo de aplicaciones web y móviles, así como en la implementación de soluciones de software escalables.\r',
#   {'entities': [(0, 8, 'VERB'),
#     (12, 25, 'NOUN'),
#     (29, 37, 'NOUN'),
#     (38, 44, 'NOUN'),
#     (50, 56, 'VERB'),
#     (67, 73, 'NOUN'),
#     (77, 87, 'NOUN'),
#     (94, 101, 'NOUN'),
#     (102, 106, 'PROPN'),
#     (110, 119, 'NOUN'),
#     (126, 132, 'VERB'),
#     (144, 155, 'NOUN'),
#     (162, 172, 'NOUN'),
#     (176, 188, 'NOUN'),
#     (189, 192, 'NOUN'),
#     (195, 202, 'NOUN'),
#     (219, 233, 'VERB'),
#     (237, 247, 'NOUN'),
#     (251, 259, 'NOUN'),
#     (260, 270, 'NOUN')]}),
#  ('Se busca un ingeniero de software con experiencia en el desarrollo de aplicaciones web y móviles para unirse al equipo de XYZ Inc. en San Francisco.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 21, 'NOUN'),
#     (25, 33, 'NOUN'),
#     (38, 49, 'NOUN'),
#     (56, 66, 'NOUN'),
#     (70, 82, 'NOUN'),
#     (83, 86, 'NOUN'),
#     (89, 96, 'NOUN'),
#     (102, 108, 'VERB'),
#     (122, 130, 'PROPN'),
#     (134, 147, 'PROPN')]}),
#  ('Se busca un arquitecto de soluciones con experiencia en implementación de proyectos en la nube para unirse al equipo de ABC Tech en su sede en Nueva York. La persona seleccionada será responsable de diseñar soluciones escalables y sostenibles para los clientes de la compañía.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 36, 'NOUN'),
#     (56, 83, 'NOUN'),
#     (90, 94, 'NOUN'),
#     (100, 106, 'VERB'),
#     (110, 116, 'NOUN'),
#     (120, 128, 'PROPN'),
#     (135, 139, 'NOUN'),
#     (143, 154, 'PROPN'),
#     (158, 165, 'NOUN'),
#     (179, 183, 'VERB'),
#     (184, 195, 'NOUN'),
#     (199, 206, 'VERB'),
#     (207, 217, 'NOUN'),
#     (252, 260, 'NOUN'),
#     (267, 275, 'NOUN')]}),
#  ('Se busca un data scientist con experiencia en análisis de datos y modelos de aprendizaje automático para unirse al equipo de DEF Corp en su sede en Londres. La persona seleccionada trabajará en proyectos importantes para la compañía y utilizará técnicas avanzadas para extraer insights valiosos de los datos.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 26, 'NOUN'),
#     (46, 63, 'NOUN'),
#     (66, 99, 'NOUN'),
#     (105, 111, 'VERB'),
#     (115, 121, 'NOUN'),
#     (125, 133, 'PROPN'),
#     (140, 144, 'NOUN'),
#     (148, 156, 'PROPN'),
#     (160, 167, 'NOUN'),
#     (181, 190, 'VERB'),
#     (194, 203, 'NOUN'),
#     (224, 232, 'NOUN'),
#     (235, 244, 'VERB'),
#     (245, 253, 'NOUN'),
#     (269, 276, 'VERB'),
#     (277, 285, 'NOUN'),
#     (302, 307, 'NOUN')]}),
#  ('Se busca un ingeniero de software full-stack con experiencia en desarrollo de aplicaciones en React y Node.js para unirse al equipo de GHI Inc en su sede en San Francisco. La persona seleccionada será responsable de desarrollar y mantener aplicaciones web escalables y eficientes, trabajando en estrecha colaboración con el equipo de diseño y el equipo de productos.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 33, 'NOUN'),
#     (34, 44, 'NOUN'),
#     (49, 60, 'NOUN'),
#     (64, 90, 'NOUN'),
#     (94, 99, 'NOUN'),
#     (102, 109, 'NOUN'),
#     (115, 121, 'VERB'),
#     (125, 131, 'NOUN'),
#     (135, 142, 'PROPN'),
#     (149, 153, 'NOUN'),
#     (157, 171, 'PROPN'),
#     (175, 182, 'NOUN'),
#     (196, 200, 'VERB'),
#     (216, 227, 'VERB'),
#     (230, 238, 'VERB'),
#     (239, 255, 'NOUN'),
#     (281, 291, 'VERB'),
#     (304, 316, 'NOUN'),
#     (324, 340, 'NOUN'),
#     (346, 365, 'NOUN')]}),
#  ('El puesto de Ejecutivo de Ventas B2B requiere una persona altamente motivada y orientada a resultados para unirse a nuestro equipo en la región de San Francisco. El candidato ideal tiene experiencia en la venta de soluciones tecnológicas a grandes empresas y está listo para desarrollar relaciones comerciales duraderas y generar oportunidades de crecimiento.\r',
#   {'entities': [(3, 9, 'NOUN'),
#     (13, 22, 'NOUN'),
#     (26, 32, 'NOUN'),
#     (37, 45, 'VERB'),
#     (50, 57, 'NOUN'),
#     (107, 113, 'VERB'),
#     (124, 130, 'NOUN'),
#     (137, 143, 'NOUN'),
#     (147, 161, 'PROPN'),
#     (165, 174, 'NOUN'),
#     (181, 186, 'VERB'),
#     (248, 256, 'NOUN'),
#     (259, 263, 'VERB'),
#     (264, 269, 'VERB'),
#     (275, 286, 'VERB'),
#     (287, 297, 'NOUN'),
#     (298, 309, 'NOUN'),
#     (322, 329, 'VERB'),
#     (330, 343, 'NOUN'),
#     (347, 358, 'NOUN')]}),
#  ('Buscamos un Representante de Ventas Senior para unirse a nuestro equipo en Nueva York. El candidato ideal tiene una sólida trayectoria en ventas y experiencia en el sector tecnológico. Será responsable de establecer y mantener relaciones con clientes, identificar oportunidades de crecimiento y superar objetivos de ventas.\r',
#   {'entities': [(0, 8, 'VERB'),
#     (12, 25, 'NOUN'),
#     (29, 35, 'NOUN'),
#     (36, 42, 'NOUN'),
#     (48, 54, 'VERB'),
#     (65, 71, 'NOUN'),
#     (75, 86, 'PROPN'),
#     (90, 99, 'NOUN'),
#     (106, 111, 'VERB'),
#     (123, 134, 'NOUN'),
#     (138, 144, 'NOUN'),
#     (165, 171, 'NOUN'),
#     (172, 184, 'NOUN'),
#     (185, 189, 'VERB'),
#     (190, 201, 'NOUN'),
#     (205, 215, 'VERB'),
#     (218, 226, 'VERB'),
#     (227, 237, 'NOUN'),
#     (242, 250, 'NOUN'),
#     (252, 263, 'VERB'),
#     (264, 277, 'NOUN'),
#     (281, 292, 'NOUN'),
#     (295, 302, 'VERB'),
#     (303, 312, 'NOUN')]}),
#  ('Necesitamos un Director de Ventas para liderar nuestro equipo de ventas en Dallas. El candidato ideal tiene una sólida experiencia en la gestión de equipos de ventas y un historial comprobado de lograr objetivos de ventas. Será responsable de establecer estrategias de ventas, supervisar la actividad de ventas y asegurar la satisfacción del cliente.\r',
#   {'entities': [(0, 11, 'VERB'),
#     (15, 23, 'NOUN'),
#     (27, 33, 'NOUN'),
#     (39, 46, 'VERB'),
#     (55, 61, 'NOUN'),
#     (75, 82, 'PROPN'),
#     (86, 95, 'NOUN'),
#     (102, 118, 'VERB'),
#     (119, 130, 'NOUN'),
#     (137, 144, 'NOUN'),
#     (148, 155, 'NOUN'),
#     (159, 165, 'NOUN'),
#     (171, 180, 'NOUN'),
#     (202, 211, 'NOUN'),
#     (215, 222, 'NOUN'),
#     (223, 227, 'VERB'),
#     (228, 239, 'NOUN'),
#     (243, 253, 'VERB'),
#     (254, 265, 'NOUN'),
#     (269, 275, 'NOUN'),
#     (277, 287, 'VERB'),
#     (291, 300, 'NOUN'),
#     (304, 310, 'NOUN'),
#     (313, 321, 'VERB'),
#     (325, 337, 'NOUN'),
#     (342, 349, 'NOUN')]}),
#  ('Buscamos un Asistente Administrativo para unirse a nuestro equipo en la empresa ABC Inc. El candidato será responsable de apoyar al departamento de administración en tareas diarias y en el mantenimiento de registros organizados.\r',
#   {'entities': [(0, 8, 'VERB'),
#     (12, 36, 'NOUN'),
#     (42, 48, 'VERB'),
#     (59, 65, 'NOUN'),
#     (72, 79, 'NOUN'),
#     (80, 88, 'PROPN'),
#     (92, 101, 'NOUN'),
#     (102, 106, 'VERB'),
#     (107, 118, 'NOUN'),
#     (122, 128, 'VERB'),
#     (132, 144, 'NOUN'),
#     (148, 162, 'NOUN'),
#     (166, 172, 'NOUN'),
#     (189, 202, 'VERB'),
#     (206, 215, 'NOUN')]}),
#  ('La empresa XYZ busca un Coordinador de Recursos Humanos para liderar y supervisar las operaciones HR de la organización. El candidato ideal debe tener experiencia en gestión de recursos humanos y habilidades de liderazgo sólidas.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (15, 20, 'VERB'),
#     (24, 55, 'NOUN'),
#     (61, 68, 'VERB'),
#     (71, 81, 'VERB'),
#     (86, 97, 'NOUN'),
#     (98, 100, 'NOUN'),
#     (107, 120, 'NOUN'),
#     (124, 133, 'NOUN'),
#     (140, 144, 'VERB'),
#     (145, 150, 'VERB'),
#     (151, 162, 'NOUN'),
#     (166, 173, 'NOUN'),
#     (177, 193, 'NOUN'),
#     (196, 207, 'NOUN'),
#     (211, 220, 'NOUN')]}),
#  ('Se requiere un Asistente de Ventas para unirse al equipo de ventas de la empresa DEF Ltd. El candidato será responsable de apoyar a los ejecutivos de ventas en la gestión de clientes, la generación de leads y la realización de seguimiento a prospectos.\r',
#   {'entities': [(3, 11, 'VERB'),
#     (15, 34, 'NOUN'),
#     (40, 46, 'VERB'),
#     (50, 56, 'NOUN'),
#     (60, 66, 'NOUN'),
#     (73, 80, 'NOUN'),
#     (81, 89, 'PROPN'),
#     (93, 102, 'NOUN'),
#     (103, 107, 'VERB'),
#     (108, 119, 'NOUN'),
#     (123, 129, 'VERB'),
#     (136, 146, 'NOUN'),
#     (150, 156, 'NOUN'),
#     (163, 170, 'VERB'),
#     (174, 182, 'NOUN'),
#     (187, 197, 'VERB'),
#     (201, 206, 'NOUN'),
#     (212, 223, 'VERB'),
#     (227, 238, 'NOUN'),
#     (241, 251, 'NOUN')]}),
#  ('La compañía GHI busca un Contador Junior para unirse a su equipo contable. El candidato ideal tendrá experiencia en contabilidad y habilidades en la utilización de software contable. Será responsable de llevar a cabo tareas contables diarias y de brindar apoyo a la gerencia financiera.\r',
#   {'entities': [(3, 11, 'NOUN'),
#     (12, 15, 'PROPN'),
#     (16, 21, 'VERB'),
#     (25, 40, 'NOUN'),
#     (46, 52, 'VERB'),
#     (58, 64, 'NOUN'),
#     (65, 74, 'NOUN'),
#     (78, 87, 'NOUN'),
#     (88, 93, 'NOUN'),
#     (94, 100, 'VERB'),
#     (101, 112, 'NOUN'),
#     (116, 128, 'NOUN'),
#     (131, 142, 'NOUN'),
#     (149, 160, 'NOUN'),
#     (164, 172, 'NOUN'),
#     (173, 182, 'NOUN'),
#     (183, 187, 'VERB'),
#     (188, 199, 'NOUN'),
#     (203, 209, 'VERB'),
#     (212, 216, 'VERB'),
#     (217, 223, 'NOUN'),
#     (224, 233, 'NOUN'),
#     (247, 254, 'VERB'),
#     (255, 260, 'NOUN'),
#     (266, 285, 'NOUN')]}),
#  ('Se busca un Coordinador de Operaciones con experiencia en logística y gestión de equipos para unirse a la empresa XYZ. El candidato ideal tendrá una formación en administración de empresas y habilidades en liderazgo, planificación y resolución de problemas.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 38, 'NOUN'),
#     (43, 54, 'NOUN'),
#     (58, 67, 'NOUN'),
#     (70, 88, 'NOUN'),
#     (94, 100, 'VERB'),
#     (106, 113, 'NOUN'),
#     (114, 118, 'PROPN'),
#     (122, 131, 'NOUN'),
#     (138, 144, 'VERB'),
#     (149, 158, 'NOUN'),
#     (162, 188, 'NOUN'),
#     (191, 202, 'NOUN'),
#     (206, 215, 'NOUN'),
#     (217, 230, 'NOUN'),
#     (233, 256, 'NOUN')]}),
#  ('La empresa ABC está buscando un Especialista en Seguridad Operativa para garantizar la protección de sus activos y personal. El candidato ideal tendrá experiencia en implementación de políticas y procedimientos de seguridad, así como habilidades en investigación y resolución de incidentes.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (20, 28, 'VERB'),
#     (32, 67, 'NOUN'),
#     (73, 83, 'VERB'),
#     (87, 97, 'NOUN'),
#     (105, 112, 'NOUN'),
#     (115, 124, 'NOUN'),
#     (128, 137, 'NOUN'),
#     (144, 150, 'VERB'),
#     (151, 162, 'NOUN'),
#     (166, 180, 'VERB'),
#     (184, 193, 'NOUN'),
#     (196, 210, 'NOUN'),
#     (214, 223, 'NOUN'),
#     (234, 245, 'NOUN'),
#     (249, 262, 'NOUN'),
#     (265, 275, 'NOUN'),
#     (279, 289, 'NOUN')]}),
#  ('La compañía XYZ está buscando un Jefe de Operaciones para dirigir y supervisar el desempeño de sus equipos de trabajo. El candidato ideal tendrá una amplia experiencia en la gestión de proyectos y operaciones, así como habilidades en la toma de decisiones y resolución de problemas.\r',
#   {'entities': [(3, 11, 'NOUN'),
#     (12, 15, 'PROPN'),
#     (21, 29, 'VERB'),
#     (33, 52, 'NOUN'),
#     (58, 65, 'VERB'),
#     (68, 78, 'VERB'),
#     (82, 91, 'NOUN'),
#     (99, 106, 'NOUN'),
#     (110, 118, 'NOUN'),
#     (122, 131, 'NOUN'),
#     (138, 144, 'VERB'),
#     (156, 167, 'NOUN'),
#     (174, 181, 'VERB'),
#     (185, 194, 'NOUN'),
#     (197, 208, 'NOUN'),
#     (219, 230, 'NOUN'),
#     (237, 241, 'NOUN'),
#     (245, 255, 'NOUN'),
#     (258, 268, 'NOUN'),
#     (272, 281, 'NOUN')]}),
#  ('La empresa ABC está buscando un Especialista en Seguridad Operativa para garantizar la protección de sus activos y personal. El candidato ideal tendrá experiencia en implementación de políticas y procedimientos de seguridad, así como habilidades en investigación y resolución de incidentes.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (20, 28, 'VERB'),
#     (32, 67, 'NOUN'),
#     (73, 83, 'VERB'),
#     (87, 97, 'NOUN'),
#     (105, 112, 'NOUN'),
#     (115, 124, 'NOUN'),
#     (128, 137, 'NOUN'),
#     (144, 150, 'VERB'),
#     (151, 162, 'NOUN'),
#     (166, 180, 'VERB'),
#     (184, 193, 'NOUN'),
#     (196, 210, 'NOUN'),
#     (214, 223, 'NOUN'),
#     (234, 245, 'NOUN'),
#     (249, 262, 'NOUN'),
#     (265, 275, 'NOUN'),
#     (279, 289, 'NOUN')]}),
#  ('La empresa ABC busca un Gerente de Recursos Humanos para supervisar y administrar todas las funciones relacionadas con los empleados. El candidato ideal deberá tener experiencia en la implementación de políticas y programas de desarrollo de personal.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (15, 20, 'VERB'),
#     (24, 31, 'NOUN'),
#     (35, 51, 'NOUN'),
#     (57, 67, 'VERB'),
#     (70, 81, 'VERB'),
#     (92, 101, 'NOUN'),
#     (123, 133, 'NOUN'),
#     (137, 146, 'NOUN'),
#     (153, 159, 'VERB'),
#     (160, 165, 'VERB'),
#     (166, 177, 'NOUN'),
#     (184, 198, 'VERB'),
#     (202, 211, 'NOUN'),
#     (214, 223, 'NOUN'),
#     (227, 237, 'NOUN'),
#     (241, 249, 'NOUN')]}),
#  ('Se busca un Director Financiero para la empresa DEF. El candidato ideal tendrá una amplia experiencia en la planificación y gestión de las finanzas de la empresa, así como en la toma de decisiones estratégicas importantes.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 31, 'NOUN'),
#     (40, 47, 'NOUN'),
#     (48, 52, 'PROPN'),
#     (56, 65, 'NOUN'),
#     (72, 78, 'VERB'),
#     (90, 101, 'NOUN'),
#     (108, 121, 'VERB'),
#     (124, 131, 'VERB'),
#     (139, 147, 'NOUN'),
#     (154, 161, 'NOUN'),
#     (178, 182, 'VERB'),
#     (186, 196, 'NOUN'),
#     (197, 209, 'NOUN')]}),
#  ('La empresa GHI está buscando un Vicepresidente de Operaciones para supervisar y optimizar los procesos operativos y logísticos de la empresa. El candidato ideal tendrá una amplia experiencia en la implementación de soluciones eficientes.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (20, 28, 'VERB'),
#     (32, 46, 'NOUN'),
#     (50, 61, 'NOUN'),
#     (67, 77, 'VERB'),
#     (80, 89, 'VERB'),
#     (94, 102, 'NOUN'),
#     (116, 126, 'NOUN'),
#     (133, 141, 'NOUN'),
#     (145, 154, 'NOUN'),
#     (161, 167, 'VERB'),
#     (179, 190, 'NOUN'),
#     (197, 211, 'VERB'),
#     (215, 225, 'NOUN')]}),
#  ('La empresa JKL está buscando un Director de Desarrollo de Negocios para liderar la expansión de la empresa a nuevos mercados y fortalecer su posición en el mercado actual. El candidato ideal tendrá una amplia experiencia en la identificación y análisis de oportunidades de negocios.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (20, 28, 'VERB'),
#     (32, 40, 'NOUN'),
#     (44, 54, 'NOUN'),
#     (58, 66, 'NOUN'),
#     (72, 79, 'VERB'),
#     (83, 92, 'VERB'),
#     (99, 106, 'NOUN'),
#     (116, 124, 'NOUN'),
#     (127, 137, 'VERB'),
#     (141, 149, 'NOUN'),
#     (175, 184, 'NOUN'),
#     (191, 197, 'VERB'),
#     (209, 220, 'NOUN'),
#     (227, 241, 'VERB'),
#     (244, 252, 'VERB'),
#     (256, 269, 'NOUN'),
#     (273, 281, 'NOUN')]}),
#  ('La compañía XYZ está buscando un Director de Marketing para liderar la estrategia de marketing y crecimiento de la marca. El candidato ideal tendrá experiencia en el desarrollo de campañas de marketing digital y tradicionales, y en la supervisión de un equipo.\r',
#   {'entities': [(3, 11, 'NOUN'),
#     (12, 15, 'PROPN'),
#     (16, 29, 'VERB'),
#     (33, 41, 'NOUN'),
#     (45, 54, 'NOUN'),
#     (60, 67, 'VERB'),
#     (71, 81, 'NOUN'),
#     (85, 94, 'NOUN'),
#     (97, 108, 'NOUN'),
#     (115, 121, 'NOUN'),
#     (125, 134, 'NOUN'),
#     (141, 147, 'VERB'),
#     (148, 159, 'NOUN'),
#     (166, 176, 'VERB'),
#     (180, 188, 'NOUN'),
#     (192, 201, 'NOUN'),
#     (235, 246, 'VERB'),
#     (253, 259, 'NOUN')]}),
#  ('La empresa ABC está buscando un Experto en Marketing Digital para liderar la implementación de estrategias de marketing digital y mejorar la presencia en línea de la marca. El candidato ideal tendrá experiencia en SEO, SEM, email marketing y publicidad en redes sociales.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (15, 28, 'VERB'),
#     (32, 39, 'NOUN'),
#     (43, 60, 'NOUN'),
#     (66, 73, 'VERB'),
#     (77, 91, 'NOUN'),
#     (95, 106, 'NOUN'),
#     (110, 127, 'NOUN'),
#     (141, 150, 'NOUN'),
#     (154, 159, 'NOUN'),
#     (166, 172, 'NOUN'),
#     (176, 185, 'NOUN'),
#     (192, 198, 'VERB'),
#     (199, 210, 'VERB'),
#     (214, 217, 'NOUN'),
#     (219, 222, 'NOUN'),
#     (224, 239, 'NOUN'),
#     (242, 252, 'NOUN'),
#     (256, 270, 'NOUN')]}),
#  ('La empresa XYZ está buscando un Especialista en Campañas Publicitarias para desarrollar y ejecutar campañas de publicidad integradas a través de diferentes canales. El candidato ideal tendrá una fuerte comprensión de la investigación de mercado, segmentación de audiencias y desarrollo de estrategias de branding.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 14, 'PROPN'),
#     (15, 28, 'VERB'),
#     (32, 44, 'NOUN'),
#     (48, 70, 'NOUN'),
#     (76, 87, 'VERB'),
#     (90, 98, 'VERB'),
#     (99, 121, 'NOUN'),
#     (156, 164, 'NOUN'),
#     (168, 177, 'NOUN'),
#     (184, 190, 'VERB'),
#     (202, 213, 'VERB'),
#     (220, 244, 'NOUN'),
#     (246, 272, 'NOUN'),
#     (275, 300, 'NOUN'),
#     (304, 312, 'NOUN')]}),
#  ('Se busca un Analista Financiero para unirse a una empresa líder en el sector bancario. El candidato será responsable de llevar a cabo análisis financieros detallados y presentar recomendaciones para la toma de decisiones comerciales y estratégicas.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 31, 'NOUN'),
#     (37, 43, 'VERB'),
#     (50, 57, 'NOUN'),
#     (70, 86, 'NOUN'),
#     (90, 99, 'NOUN'),
#     (100, 116, 'VERB'),
#     (120, 133, 'VERB'),
#     (134, 154, 'NOUN'),
#     (168, 177, 'VERB'),
#     (178, 193, 'NOUN'),
#     (210, 232, 'NOUN'),
#     (235, 247, 'NOUN')]}),
#  ('Se busca un Asistente de Gerente de Inversiones para una empresa de gestión de activos en crecimiento. El candidato será responsable de ayudar en la investigación de oportunidades de inversión, monitorear y evaluar el desempeño de los portafolios, y preparar informes para los clientes y los gerentes de inversiones.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 47, 'NOUN'),
#     (57, 86, 'NOUN'),
#     (106, 115, 'NOUN'),
#     (136, 142, 'VERB'),
#     (149, 162, 'NOUN'),
#     (166, 192, 'NOUN'),
#     (194, 204, 'VERB'),
#     (207, 214, 'VERB'),
#     (218, 227, 'NOUN'),
#     (235, 246, 'NOUN'),
#     (250, 258, 'VERB'),
#     (259, 267, 'NOUN'),
#     (277, 285, 'NOUN'),
#     (292, 315, 'NOUN')]}),
#  ('Se busca un Analista de Riesgo Financiero para una firma de inversiones internacional. El candidato será responsable de evaluar y monitorear los riesgos financieros asociados con las inversiones, desarrollar estrategias para mitigar esos riesgos, y preparar informes regulares para el equipo de inversiones y los clientes.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 41, 'NOUN'),
#     (51, 71, 'NOUN'),
#     (90, 99, 'NOUN'),
#     (120, 127, 'VERB'),
#     (130, 140, 'VERB'),
#     (145, 164, 'NOUN'),
#     (183, 194, 'NOUN'),
#     (196, 207, 'VERB'),
#     (208, 219, 'NOUN'),
#     (249, 257, 'VERB'),
#     (258, 276, 'NOUN'),
#     (285, 306, 'NOUN'),
#     (313, 321, 'NOUN')]}),
#  ('El abogado senior será responsable de proporcionar asesoramiento legal a la empresa en diversas áreas, incluyendo contratos, propiedad intelectual, litigios y cumplimiento normativo. Además, trabajará estrechamente con otras áreas de la empresa para garantizar la integridad y el cumplimiento con las leyes y regulaciones aplicables.\r',
#   {'entities': [(3, 10, 'NOUN'),
#     (11, 17, 'NOUN'),
#     (18, 22, 'VERB'),
#     (23, 34, 'NOUN'),
#     (38, 50, 'VERB'),
#     (51, 70, 'NOUN'),
#     (76, 83, 'PROPN'),
#     (87, 101, 'NOUN'),
#     (114, 123, 'NOUN'),
#     (125, 146, 'NOUN'),
#     (148, 156, 'NOUN'),
#     (159, 182, 'NOUN'),
#     (191, 200, 'VERB'),
#     (225, 244, 'NOUN'),
#     (250, 260, 'VERB'),
#     (264, 274, 'NOUN'),
#     (280, 292, 'NOUN'),
#     (301, 306, 'NOUN'),
#     (309, 321, 'NOUN'),
#     (322, 332, 'NOUN')]}),
#  ('Se busca un Contador/a Senior para unirse a la firma de contabilidad y auditoría Smith & Associates. El/la candidato/a deberá tener experiencia en la elaboración y revisión de estados financieros y en la planificación fiscal. Se requiere un título universitario en contabilidad y una certificación activa.\r',
#   {'entities': [(3, 8, 'VERB'),
#     (12, 22, 'NOUN'),
#     (23, 29, 'NOUN'),
#     (35, 41, 'VERB'),
#     (47, 52, 'NOUN'),
#     (56, 68, 'NOUN'),
#     (71, 80, 'NOUN'),
#     (81, 100, 'PROPN'),
#     (107, 118, 'NOUN'),
#     (126, 131, 'VERB'),
#     (132, 143, 'NOUN'),
#     (150, 161, 'VERB'),
#     (164, 172, 'VERB'),
#     (176, 195, 'NOUN'),
#     (229, 237, 'VERB'),
#     (241, 261, 'NOUN'),
#     (265, 277, 'NOUN'),
#     (284, 297, 'NOUN')]}),
#  ('Se requiere un auditor senior para unirse a la empresa Ernst & Young. El candidato ideal debe tener al menos 5 años de experiencia en auditoría financiera y haber obtenido su certificación en contabilidad. La posición incluye la supervisión de equipos y la realización de auditorías en una variedad de industrias.\r',
#   {'entities': [(3, 11, 'VERB'),
#     (15, 22, 'NOUN'),
#     (23, 29, 'NOUN'),
#     (35, 41, 'VERB'),
#     (47, 54, 'NOUN'),
#     (55, 69, 'PROPN'),
#     (73, 82, 'NOUN'),
#     (89, 93, 'VERB'),
#     (94, 99, 'VERB'),
#     (119, 130, 'NOUN'),
#     (134, 154, 'NOUN'),
#     (157, 171, 'VERB'),
#     (175, 188, 'NOUN'),
#     (192, 205, 'NOUN'),
#     (209, 217, 'NOUN'),
#     (218, 225, 'VERB'),
#     (229, 240, 'VERB'),
#     (244, 251, 'NOUN'),
#     (257, 268, 'VERB'),
#     (272, 282, 'NOUN'),
#     (290, 298, 'NOUN'),
#     (302, 312, 'NOUN')]}),
#  ('"ACCA": Association of Chartered Certified Accountants.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 54, 'PROPN')]}),
#  ('"CFE": Certified Fraud Examiner.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 31, 'PROPN')]}),
#  ('"CFA": Chartered Financial Analyst.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 34, 'PROPN')]}),
#  ('"CPA": Certified Public Accountant.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 34, 'PROPN')]}),
#  ('"CMA": Certified Management Accountant.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 38, 'PROPN')]}),
#  ('"CFP": Certified Financial Planner.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 34, 'PROPN')]}),
#  ('"CIA": Certified Internal Auditor.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 33, 'PROPN')]}),
#  ('"CFM": Certified Financial Manager.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 34, 'PROPN')]}),
#  ('"FRM": Financial Risk Manager.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 29, 'PROPN')]}),
#  ('"CGEIT": Certified in the Governance of Enterprise IT.\r',
#   {'entities': [(1, 6, 'PROPN'), (9, 53, 'PROPN')]}),
#  ('"CISA": Certified Information Systems Auditor.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 45, 'PROPN')]}),
#  ('"CTP": Certified Treasury Professional.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 38, 'PROPN')]}),
#  ('"CGMA": Chartered Global Management Accountant.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 46, 'PROPN')]}),
#  ('"CISSP": Certified Information Systems Security Professional.\r',
#   {'entities': [(1, 6, 'PROPN'), (9, 60, 'PROPN')]}),
#  ('"CEH": Certified Ethical Hacker.\r',
#   {'entities': [(1, 4, 'PROPN'), (7, 31, 'PROPN')]}),
#  ('"CISM": Certified Information Security Manager.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 46, 'PROPN')]}),
#  ('"CCSP": Certified Cloud Security Professional.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 45, 'PROPN')]}),
#  ('"CompTIA Security+": CompTIA Security+.\r',
#   {'entities': [(1, 18, 'PROPN'), (21, 38, 'PROPN')]}),
#  ('"GSEC": GIAC Security Essentials.\r',
#   {'entities': [(1, 5, 'PROPN'), (8, 32, 'PROPN')]}),
#  ('"CISSP-ISSAP": Certified Information Systems Security Professional (CISSP-ISSAP).\r',
#   {'entities': [(1, 12, 'PROPN'), (15, 66, 'PROPN')]}),
#  ('"CISSP-ISSMP": Certified Information Systems Security Professional (CISSP-ISSMP).',
#   {'entities': [(1, 12, 'PROPN'), (15, 66, 'PROPN')]}),
#  ('XYZ\r', {'entities': [(0, 3, 'NOUN')]}),
#  ('XYZ Inc.\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('San Francisco\r', {'entities': [(0, 13, 'NOUN')]}),
#  ('ABC Tech\r', {'entities': [(0, 8, 'NOUN')]}),
#  ('Nueva York\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('DEF Corp\r', {'entities': [(0, 8, 'NOUN')]}),
#  ('Londres\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('GHI Inc\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('San Francisco\r', {'entities': [(0, 13, 'NOUN')]}),
#  ('responsabilidad\r', {'entities': [(0, 15, 'NOUN')]}),
#  ('colaborar\r', {'entities': [(0, 9, 'VERB')]}),
#  ('Nueva York\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('Dallas\r', {'entities': [(0, 6, 'NOUN')]}),
#  ('supervisar\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('tener\r', {'entities': [(0, 5, 'VERB')]}),
#  ('tener una\r', {'entities': [(0, 9, 'VERB')]}),
#  ('tener un historial\r', {'entities': [(0, 18, 'VERB')]}),
#  ('ABC Inc\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('mantenimiento\r', {'entities': [(0, 13, 'NOUN')]}),
#  ('DEF Ltd\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('apoyar\r', {'entities': [(0, 6, 'NOUN')]}),
#  ('gestión\r', {'entities': [(0, 7, 'NOUN')]}),
#  ('realización\r', {'entities': [(0, 11, 'NOUN')]}),
#  ('GHI\r', {'entities': [(0, 3, 'NOUN')]}),
#  ('implementación\r', {'entities': [(0, 14, 'NOUN')]}),
#  ('supervisión\r', {'entities': [(0, 11, 'NOUN')]}),
#  ('administración\r', {'entities': [(0, 14, 'NOUN')]}),
#  ('planificación\r', {'entities': [(0, 13, 'NOUN')]}),
#  ('toma\r', {'entities': [(0, 4, 'NOUN')]}),
#  ('optimización\r', {'entities': [(0, 12, 'NOUN')]}),
#  ('liderazgo\r', {'entities': [(0, 9, 'NOUN')]}),
#  ('expansión\r', {'entities': [(0, 9, 'NOUN')]}),
#  ('identificación\r', {'entities': [(0, 14, 'NOUN')]}),
#  ('análisis\r', {'entities': [(0, 8, 'NOUN')]}),
#  ('desarrollo\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('experiencia\r', {'entities': [(0, 11, 'NOUN')]}),
#  ('ejecución\r', {'entities': [(0, 9, 'NOUN')]}),
#  ('fuerte comprensión\r', {'entities': [(0, 18, 'NOUN')]}),
#  ('monitoreo\r', {'entities': [(0, 9, 'NOUN')]}),
#  ('evaluación\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('investigar\r', {'entities': [(0, 10, 'VERB')]}),
#  ('mitigación\r', {'entities': [(0, 10, 'NOUN')]}),
#  ('empresas\r', {'entities': [(0, 8, 'NOUN')]}),
#  ('elaboración\r', {'entities': [(0, 11, 'NOUN')]}),
#  ('revisión\r', {'entities': [(0, 8, 'NOUN')]}),
#  ('realización\r', {'entities': [(0, 11, 'NOUN')]})]

# %%
# !python -m spacy download es_core_news_sm
# Out:
# 2023-02-13 08:24:32.447741: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-02-13 08:24:33.709885: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-13 08:24:33.710032: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/lib64-nvidia
# 2023-02-13 08:24:33.710054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting es-core-news-sm==3.4.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/es_core_news_sm-3.4.0/es_core_news_sm-3.4.0-py3-none-any.whl (12.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.5.0,>=3.4.0 in /usr/local/lib/python3.8/dist-packages (from es-core-news-sm==3.4.0) (3.4.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.21.6)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (57.4.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.8)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.7)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.4.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.10.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.10 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.0.12)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.64.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (3.3.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.11.3)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.0)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (8.1.7)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.10.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.0.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.25.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (23.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.8/dist-packages (from spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (6.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.8/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.4.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2022.12.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.10)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.8/dist-packages (from thinc<8.2.0,>=8.1.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.8/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from jinja2->spacy<3.5.0,>=3.4.0->es-core-news-sm==3.4.0) (2.0.1)
# Installing collected packages: es-core-news-sm
# Successfully installed es-core-news-sm-3.4.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('es_core_news_sm')

# %%
import pandas as pd
import os
from tqdm import tqdm
import spacy
from spacy.tokens import DocBin

#nlp = spacy.blank("en") # load a new spacy model
nlp = spacy.load("es_core_news_sm") # load other spacy model

db = DocBin() # create a DocBin object

for text, annot in tqdm(train_data): # data in previous format
    doc = nlp.make_doc(text) # create doc object from text
    ents = []
    for start, end, label in annot["entities"]: # add character indexes
        span = doc.char_span(start, end, label=label, alignment_mode="contract")
        if span is None:
            print("Skipping entity")
        else:
            ents.append(span)
    doc.ents = ents # label the text with the ents
    db.add(doc)
db.to_disk("./train.spacy") # save the docbin object
# Out:
# 100%|██████████| 96/96 [00:00<00:00, 3048.28it/s]
